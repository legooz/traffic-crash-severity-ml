# %%
from pathlib import Path
import os

# Set PROJECT_DATA_DIR before launching Jupyter to use data stored elsewhere.
PROJECT_ROOT = Path.cwd()
while not (PROJECT_ROOT / ".gitignore").exists() and PROJECT_ROOT != PROJECT_ROOT.parent:
    PROJECT_ROOT = PROJECT_ROOT.parent
DATA_DIR = Path(os.environ.get("PROJECT_DATA_DIR", str(PROJECT_ROOT / "data"))).expanduser()

# %%
import pandas as pd

# Load the two datasets
df1 = pd.read_csv(str(DATA_DIR / 'accident.csv'))
df2 = pd.read_csv(str(DATA_DIR / 'accident.csv'))

# Keep only the columns that exist in both
common_cols = df1.columns.intersection(df2.columns)
df1_common = df1[common_cols]
df2_common = df2[common_cols]


common_cols = common_cols.tolist()
print("Columns in both datasets:", common_cols)

# %%
import pandas as pd

# Load the two datasets
df1 = pd.read_csv(str(DATA_DIR / 'damage.csv'))
df2 = pd.read_csv(str(DATA_DIR / 'damage.csv'))

# Keep only the columns that exist in both
common_cols = df1.columns.intersection(df2.columns)
df1_common = df1[common_cols]
df2_common = df2[common_cols]


common_cols = common_cols.tolist()
print("Columns in both datasets:", common_cols)

# %%
import pandas as pd

# Load the two datasets
df1 = pd.read_csv(str(DATA_DIR / 'distract.csv'))
df2 = pd.read_csv(str(DATA_DIR / 'distract.csv'))

# Keep only the columns that exist in both
common_cols = df1.columns.intersection(df2.columns)
df1_common = df1[common_cols]
df2_common = df2[common_cols]


common_cols = common_cols.tolist()
print("Columns in both datasets:", common_cols)

# %%
import pandas as pd

# Load the two datasets
df1 = pd.read_csv(str(DATA_DIR / 'drimpair.csv'))
df2 = pd.read_csv(str(DATA_DIR / 'drimpair.csv'))

# Keep only the columns that exist in both
common_cols = df1.columns.intersection(df2.columns)
df1_common = df1[common_cols]
df2_common = df2[common_cols]


common_cols = common_cols.tolist()
print("Columns in both datasets:", common_cols)

# %%
import pandas as pd

# Load the two datasets
df1 = pd.read_csv(str(DATA_DIR / 'person.csv'))
df2 = pd.read_csv(str(DATA_DIR / 'person.csv'))

# Keep only the columns that exist in both
common_cols = df1.columns.intersection(df2.columns)
df1_common = df1[common_cols]
df2_common = df2[common_cols]


common_cols = common_cols.tolist()
print("Columns in both datasets:", common_cols)

# %%
import pandas as pd

# Load the two datasets
df1 = pd.read_csv(str(DATA_DIR / 'vehicle.csv'))
df2 = pd.read_csv(str(DATA_DIR / 'vehicle.csv'))

# Keep only the columns that exist in both
common_cols = df1.columns.intersection(df2.columns)
df1_common = df1[common_cols]
df2_common = df2[common_cols]


common_cols = common_cols.tolist()
print("Columns in both datasets:", common_cols)

# %%
import pandas as pd

# Load the two datasets
df1 = pd.read_csv(str(DATA_DIR / 'vision.csv'))
df2 = pd.read_csv(str(DATA_DIR / 'vision.csv'))

# Keep only the columns that exist in both
common_cols = df1.columns.intersection(df2.columns)
df1_common = df1[common_cols]
df2_common = df2[common_cols]


common_cols = common_cols.tolist()
print("Columns in both datasets:", common_cols)

# %%
import pandas as pd

# Load the two datasets
df1 = pd.read_csv(str(DATA_DIR / 'weather.csv'))
df2 = pd.read_csv(str(DATA_DIR / 'weather.csv'))

# Keep only the columns that exist in both
common_cols = df1.columns.intersection(df2.columns)


common_cols = common_cols.tolist()
print("Columns in both datasets:", common_cols)

# %%
#Columns in both datasets: ['PEDS', 'PERNOTMVIT', 'VE_TOTAL', 'VE_FORMS', 'PVH_INVL', 'PERMVIT', 
# 'MONTH', 'MONTHNAME', 'DAY_WEEK', 'DAY_WEEKNAME', 'YEAR', 'HOUR', 'HOURNAME', 'MINUTE', 'MINUTENAME',
#  'HARM_EV', 'HARM_EVNAME', 'MAN_COLL', 'MAN_COLLNAME', 'RELJCT1', 'RELJCT1NAME', 'RELJCT2', 
# 'RELJCT2NAME', 'TYP_INT', 'TYP_INTNAME', 'REL_ROAD', 'REL_ROADNAME', 'WRK_ZONE', 'WRK_ZONENAME', 
# 'LGT_COND', 'LGT_CONDNAME', 'WEATHER', 'WEATHERNAME', 'SCH_BUS', 'SCH_BUSNAME']

# Columns in both datasets: ['VEH_NO', 'DAMAGE', 'DAMAGENAME']

# Columns in both datasets: ['VEH_NO', 'DRDISTRACT', 'DRDISTRACTNAME']

# Columns in both datasets: ['VEH_NO', 'DRIMPAIR', 'DRIMPAIRNAME']

# Columns in both datasets: ['VE_FORMS', 'VEH_NO', 'PER_NO', 'MONTH', 'MONTHNAME', 'HOUR', 'HOURNAME',
#  'MINUTE', 'MINUTENAME', 'HARM_EV', 'HARM_EVNAME', 'MAN_COLL', 'MAN_COLLNAME', 'SCH_BUS', 
# 'SCH_BUSNAME', 'MOD_YEAR', 'MOD_YEARNAME', 'VPICMAKE', 'VPICMAKENAME', 'VPICMODEL', 'VPICMODELNAME',
#  'VPICBODYCLASS', 'VPICBODYCLASSNAME', 'MAKE', 'MAKENAME', 'BODY_TYP', 'BODY_TYPNAME', 'ICFINALBODY',
#  'ICFINALBODYNAME', 'GVWR_FROM', 'GVWR_FROMNAME', 'GVWR_TO', 'GVWR_TONAME', 'TOW_VEH', 'TOW_VEHNAME',
#  'SPEC_USE', 'SPEC_USENAME', 'EMER_USE', 'EMER_USENAME', 'ROLLOVER', 'ROLLOVERNAME', 'IMPACT1',
#  'IMPACT1NAME', 'FIRE_EXP', 'FIRE_EXPNAME', 'MAK_MOD', 'MAK_MODNAME', 'AGE', 'AGENAME', 'SEX',
#  'SEXNAME', 'PER_TYP', 'PER_TYPNAME', 'DEVTYPE', 'DEVTYPENAME', 'DEVMOTOR', 'DEVMOTORNAME',
#  'INJ_SEV', 'INJ_SEVNAME', 'SEAT_POS', 'SEAT_POSNAME', 'REST_USE', 'REST_USENAME', 'REST_MIS',
#  'REST_MISNAME', 'HELM_USE', 'HELM_USENAME', 'HELM_MIS', 'HELM_MISNAME', 'AIR_BAG', 'AIR_BAGNAME',
#  'EJECTION', 'EJECTIONNAME', 'DRINKING', 'DRINKINGNAME', 'ALC_STATUS', 'ALC_STATUSNAME', 'ATST_TYP',
#  'ATST_TYPNAME', 'ALC_RES', 'ALC_RESNAME', 'DRUGS', 'DRUGSNAME', 'HOSPITAL', 'HOSPITALNAME',
#  'STR_VEH', 'LOCATION', 'LOCATIONNAME']

# Columns in both datasets: ['VEH_NO', 'VE_FORMS', 'MONTH', 'MONTHNAME', 'HOUR', 'HOURNAME', 'MINUTE',
#  'MINUTENAME', 'HARM_EV', 'HARM_EVNAME', 'MAN_COLL', 'MAN_COLLNAME', 'NUMOCCS', 'NUMOCCSNAME',
#  'UNITTYPE', 'UNITTYPENAME', 'HIT_RUN', 'HIT_RUNNAME', 'VIN', 'VINNAME', 'MOD_YEAR', 'MOD_YEARNAME',
#  'VPICMAKE', 'VPICMAKENAME', 'VPICMODEL', 'VPICMODELNAME', 'VPICBODYCLASS', 'VPICBODYCLASSNAME',
#  'MAKE', 'MAKENAME', 'MODEL', 'BODY_TYP', 'BODY_TYPNAME', 'ICFINALBODY', 'ICFINALBODYNAME',
#  'GVWR_FROM', 'GVWR_FROMNAME', 'GVWR_TO', 'GVWR_TONAME', 'TOW_VEH', 'TOW_VEHNAME', 'TRLR1VIN',
#  'TRLR1VINNAME', 'TRLR2VIN', 'TRLR2VINNAME', 'TRLR3VIN', 'TRLR3VINNAME', 'TRLR1GVWR',
#  'TRLR1GVWRNAME', 'TRLR2GVWR', 'TRLR2GVWRNAME', 'TRLR3GVWR', 'TRLR3GVWRNAME', 'J_KNIFE',
#  'J_KNIFENAME', 'MCARR_ID', 'MCARR_IDNAME', 'MCARR_I1', 'MCARR_I1NAME', 'MCARR_I2', 'MCARR_I2NAME',
#  'CARGO_BT', 'CARGO_BTNAME', 'HAZ_INV', 'HAZ_INVNAME', 'HAZ_PLAC', 'HAZ_PLACNAME', 'HAZ_ID'
# , 'HAZ_IDNAME', 'HAZ_CNO', 'HAZ_CNONAME', 'HAZ_REL', 'HAZ_RELNAME', 'BUS_USE', 'BUS_USENAME',
#  'SPEC_USE', 'SPEC_USENAME', 'EMER_USE', 'EMER_USENAME', 'TRAV_SP', 'TRAV_SPNAME', 'UNDEROVERRIDE',
#  'UNDEROVERRIDENAME', 'ROLLOVER', 'ROLLOVERNAME', 'ROLINLOC', 'ROLINLOCNAME', 'IMPACT1',
#  'IMPACT1NAME', 'DEFORMED', 'DEFORMEDNAME', 'TOWED', 'TOWEDNAME', 'M_HARM', 'M_HARMNAME',
#  'FIRE_EXP', 'FIRE_EXPNAME', 'DR_PRES', 'DR_PRESNAME', 'MAK_MOD', 'MAK_MODNAME', 'DR_ZIP',
#  'DR_ZIPNAME', 'SPEEDREL', 'SPEEDRELNAME', 'VTRAFWAY', 'VTRAFWAYNAME', 'VNUM_LAN', 'VNUM_LANNAME',
#  'VSPD_LIM', 'VSPD_LIMNAME', 'VALIGN', 'VALIGNNAME', 'VPROFILE', 'VPROFILENAME', 'VSURCOND',
#  'VSURCONDNAME', 'VTRAFCON', 'VTRAFCONNAME', 'VTCONT_F', 'VTCONT_FNAME', 'P_CRASH1', 'P_CRASH1NAME',
#  'P_CRASH2', 'P_CRASH2NAME', 'P_CRASH3', 'P_CRASH3NAME', 'PCRASH4', 'PCRASH4NAME', 'PCRASH5', 
# 'PCRASH5NAME', 'ACC_CONFIG', 'ACC_CONFIGNAME']

# Columns in both datasets: ['VEH_NO', 'VISION', 'VISIONNAME']

# Columns in both datasets: ['WEATHER', 'WEATHERNAME']

# %%
# Chosen features

# ['PEDS', 'PERNOTMVIT', 'VE_TOTAL', 'VE_FORMS', 'PVH_INVL', 'PERMVIT', 
# 'MONTH', 'MONTHNAME', 'DAY_WEEK', 'YEAR', 'HOUR', 'HOURNAME', 'MINUTE',
#  'HARM_EV', 'MAN_COLL', 'RELJCT1', 'RELJCT2', 'TYP_INT', 'REL_ROAD', 'WRK_ZONE', 
# 'LGT_COND', 'WEATHER', 'WEATHERNAME', 'SCH_BUS']

# ['VEH_NO', 'DAMAGE', 'DAMAGENAME']

# ['VEH_NO', 'DRDISTRACT', 'DRDISTRACTNAME']

# ['VEH_NO', 'DRIMPAIR', 'DRIMPAIRNAME']

# Columns in both datasets: ['VE_FORMS', 'VEH_NO', 'PER_NO', 'MONTH', 'MONTHNAME', 'HOUR', 
#  'MINUTE', 'HARM_EV', 'MOD_YEAR', 'VPICMAKE', 'VPICMODEL', 'VPICBODYCLASS', 'MAKE', 'BODY_TYP', 
#  'SPEC_USE', 'ROLLOVER', 'IMPACT1',
#  'FIRE_EXP', 'MAK_MOD', 'AGE', 'SEX',
#  'PER_TYP', 
#  'INJ_SEV', 'REST_USE', 'REST_MIS',
#  'HELM_USE', 'HELM_MIS', 'AIR_BAG', 
#  'EJECTION', 'DRINKING', 'ALC_STATUS', 'ATST_TYP', 'ALC_RES', 'DRUGS',
#  'STR_VEH', 'LOCATION']

# Columns in both datasets: ['VEH_NO', 'VE_FORMS', 'MONTH', 'HOUR', 'MINUTE',
#  'HARM_EV', 'NUMOCCS', 'HIT_RUN', 'VIN', 'MOD_YEAR', 'VPICMAKE', 'VPICMODEL', 'VPICBODYCLASS',
#  'MAKE', 'MODEL', 'BODY_TYP', 'TOW_VEH', 'CARGO_BT', , 'HAZ_INV', 
# 
#  'EMER_USE', 'TRAV_SP',
#
#  'DR_PRES', 'MAK_MOD', 'MAK_MODNAME', 'DR_ZIP',
#   'SPEEDREL', 'VTRAFWAY',
#  'VSPD_LIM', 'VSURCOND']

# Columns in both datasets: ['VEH_NO', 'VISION', 'VISIONNAME']

# Columns in both datasets: ['WEATHER', 'WEATHERNAME']

# %%
cols_accident = [ 'CASENUM',
    'PEDS', 'PERNOTMVIT', 'VE_TOTAL',  'PVH_INVL', 'PERMVIT', 
    'MONTH','DAY_WEEK', 'YEAR', 'HOUR', 'MINUTE',
    'HARM_EV', 'MAN_COLL', 'TYP_INT', 'REL_ROAD', 'WRK_ZONE', 
    'LGT_COND', 'WEATHER',
 ]

cols_distract = [ 'CASENUM',
    'VEH_NO', 'DRDISTRACT',
]

cols_drimpair = [ 'CASENUM',
    'VEH_NO', 'DRIMPAIR',
]

cols_person = [ 'CASENUM',
    'VEH_NO', 'PER_NO',  
    'SPEC_USE', 
    'AGE', 'SEX', 'PER_TYP', 'INJ_SEV', 'REST_USE', 'REST_MIS', 'HELM_USE', 
    'HELM_MIS', 'AIR_BAG', 'EJECTION', 'DRINKING', 'ALC_STATUS', 'ATST_TYP', 'ALC_RES', 'DRUGS', 
    'STR_VEH', 'LOCATION'
]

cols_vehicle = [ 'CASENUM',
    'VEH_NO', 'VE_FORMS', 'NUMOCCS', 'HIT_RUN', 'VIN', 
    'MOD_YEAR', 'VPICMAKE', 'VPICMODEL', 'VPICBODYCLASS', 'MAKE', 'MODEL', 'BODY_TYP', 'TOW_VEH', 
    'CARGO_BT', 'HAZ_INV', 'EMER_USE', 'TRAV_SP', 'DR_PRES', 'MAK_MOD', 'DR_ZIP', 'SPEEDREL', 
    'VTRAFWAY', 'VSPD_LIM', 'VSURCOND'
]

cols_vision = [ 'CASENUM',
    'VEH_NO', 'VISION', 
]

# %%
import pandas as pd
import os


# script_dir = os.getcwd()

# csv_path = os.path.join(script_dir, str(DATA_DIR / 'accident.csv'))



#
csv_path = str(DATA_DIR / 'accident.csv')

df = pd.read_csv(csv_path, usecols=cols_accident)

df.to_csv(str(DATA_DIR / 'AI-UNITE_CRSS_accident_subset.csv'), index=False)

#
csv_path = str(DATA_DIR / 'distract.csv')

df = pd.read_csv(csv_path, usecols=cols_distract)

df.to_csv(str(DATA_DIR / 'AI-UNITE_CRSS_distract_subset.csv'), index=False)

#
csv_path = str(DATA_DIR / 'drimpair.csv')
df = pd.read_csv(csv_path, usecols=cols_drimpair)

df.to_csv(str(DATA_DIR / 'AI-UNITE_CRSS_drimpair_subset.csv'), index=False)

#
csv_path = str(DATA_DIR / 'vehicle.csv')
df = pd.read_csv(csv_path, usecols=cols_vehicle)

df.to_csv(str(DATA_DIR / 'AI-UNITE_CRSS_vehicle_subset.csv'), index=False)

#
csv_path = str(DATA_DIR / 'person.csv')
df = pd.read_csv(csv_path, usecols=cols_person)

df.to_csv(str(DATA_DIR / 'AI-UNITE_CRSS_person_subset.csv'), index=False)

#
csv_path = str(DATA_DIR / 'vision.csv')
df = pd.read_csv(csv_path, usecols=cols_vision)

df.to_csv(str(DATA_DIR / 'AI-UNITE_CRSS_vision_subset.csv'), index=False)

#

# %%
df_person = pd.read_csv(str(DATA_DIR / 'AI-UNITE_CRSS_accident_subset.csv'))
print(df_person.columns.tolist())
print(df_person.dtypes)
print(df_person.shape)

# %%
df_vehicle = pd.read_csv(str(DATA_DIR / 'AI-UNITE_CRSS_vehicle_subset.csv'))
df_accident = pd.read_csv(str(DATA_DIR / 'AI-UNITE_CRSS_accident_subset.csv'))

matching_rows = df_vehicle[df_vehicle['CASENUM'].isin(df_accident['CASENUM'])]

df_merged = df_vehicle.merge(
    df_accident,
    how="left",
    left_on="CASENUM",
    right_on="CASENUM",    
)



df_merged.to_csv(str(DATA_DIR / 'AI-UNITE_CRSS_accident_vehicle_merge.csv'), index=False)
print(df_merged.shape)

# %%
df_merged = pd.read_csv(str(DATA_DIR / 'AI-UNITE_CRSS_accident_vehicle_merge.csv'))
df_person = pd.read_csv(str(DATA_DIR / 'AI-UNITE_CRSS_person_subset.csv'))

print(df_person.columns.tolist())
df_person_drivers = df_person[df_person["PER_TYP"] == 1].copy()


df_person_drivers['merge_idx'] = df_person_drivers.groupby('CASENUM').cumcount()
df_merged['merge_idx'] = df_merged.groupby('CASENUM').cumcount()

matching_rows = df_merged[df_merged['CASENUM'].isin(df_person['CASENUM'])]

df_merged = df_merged.merge(
    df_person_drivers,
    how="left",
    on=["CASENUM", "VEH_NO"],
)

print(matching_rows)


df_merged = df_merged.rename(columns={'merge_idx_x': 'merge_idx'})
df_merged = df_merged.rename(columns={'merge_idx_y': 'merge_idx'})
df_merged = df_merged.drop(columns = 'merge_idx')

df_merged.to_csv(str(DATA_DIR / 'AI-UNITE_CRSS_accident_person_vehicle_merge.csv'), index=False)

# %%
import pandas as pd

df_merged = pd.read_csv(str(DATA_DIR / 'AI-UNITE_CRSS_accident_person_vehicle_merge.csv'))
df_drimpair = pd.read_csv(str(DATA_DIR / 'AI-UNITE_CRSS_drimpair_subset.csv'))


common = df_merged['CASENUM'].isin(df_merged['CASENUM'])
df_merged = df_merged[common].copy()
df_drimpair = df_drimpair[df_drimpair['CASENUM'].isin(df_merged['CASENUM'])].copy()

df_merged['merge_idx'] = df_merged.groupby('CASENUM').cumcount()
df_drimpair['merge_idx'] = df_drimpair.groupby('CASENUM').cumcount()


df_merged = df_merged.merge(
    df_drimpair,
    how='left',
    on=['CASENUM', 'merge_idx']  
)

df_merged = df_merged.rename(columns={'merge_idx_x': 'merge_idx'})
df_merged = df_merged.rename(columns={'merge_idx_y': 'merge_idx'})
df_merged = df_merged.drop(columns = 'merge_idx')

df_merged.to_csv(str(DATA_DIR / 'AI-UNITE_CRSS_accident_person_vehicle_drimpair_merge.csv'), index=False)

print(df_merged.shape)

# %%
df_merged = pd.read_csv(str(DATA_DIR / 'AI-UNITE_CRSS_accident_person_vehicle_drimpair_merge.csv'))
df_drimpair = pd.read_csv(str(DATA_DIR / 'AI-UNITE_CRSS_distract_subset.csv'))

common = df_merged['CASENUM'].isin(df_merged['CASENUM'])
df_merged = df_merged[common].copy()
df_drimpair = df_drimpair[df_drimpair['CASENUM'].isin(df_merged['CASENUM'])].copy()

df_merged['merge_idx'] = df_merged.groupby('CASENUM').cumcount()
df_drimpair['merge_idx'] = df_drimpair.groupby('CASENUM').cumcount()


df_merged = df_merged.merge(
    df_drimpair,
    how='left',
    on=['CASENUM', 'merge_idx']  
)

df_merged = df_merged.rename(columns={'merge_idx_x': 'merge_idx'})
df_merged = df_merged.rename(columns={'merge_idx_y': 'merge_idx'})
df_merged = df_merged.drop(columns = 'merge_idx')
df_merged = df_merged.drop(columns=['VEH_NO_y', 'VEH_NO_x'])
df_merged.to_csv(str(DATA_DIR / 'AI-UNITE_CRSS_accident_person_vehicle_drimpair_distract_merge.csv'), index=False)


print(df_merged.shape)
print(df_merged.columns.tolist())

# %%
df_merged = pd.read_csv(str(DATA_DIR / 'AI-UNITE_CRSS_accident_person_vehicle_drimpair_distract_merge.csv'))
df_drimpair = pd.read_csv(str(DATA_DIR / 'AI-UNITE_CRSS_vision_subset.csv'))

common = df_merged['CASENUM'].isin(df_merged['CASENUM'])
df_merged = df_merged[common].copy()
df_drimpair = df_drimpair[df_drimpair['CASENUM'].isin(df_merged['CASENUM'])].copy()

df_merged['merge_idx'] = df_merged.groupby('CASENUM').cumcount()
df_drimpair['merge_idx'] = df_drimpair.groupby('CASENUM').cumcount()


df_merged = df_merged.merge(
    df_drimpair,
    how='left',
    on=['CASENUM', 'merge_idx']  
)

df_merged = df_merged.rename(columns={'merge_idx_x': 'merge_idx'})
df_merged = df_merged.rename(columns={'merge_idx_y': 'merge_idx'})
df_merged = df_merged.drop(columns = 'merge_idx')

df_merged.to_csv(str(DATA_DIR / 'AI-UNITE_CRSS_accident_person_vehicle_drimpair_distractr_vision_merge.csv'), index=False)

df_merged.to_csv(str(DATA_DIR / 'AI-UNITE_CRSS_merged.csv'), index=False)
print(df_merged.shape)

# %%
cols_accident = [ 'ST_CASE',
    'PEDS', 'PERNOTMVIT', 'VE_TOTAL',  'PVH_INVL', 'PERMVIT', 
    'MONTH','DAY_WEEK', 'YEAR', 'HOUR', 'MINUTE',
    'HARM_EV', 'MAN_COLL', 'TYP_INT', 'REL_ROAD', 'WRK_ZONE', 
    'LGT_COND', 'WEATHER',
 ]

cols_distract = [ 'ST_CASE',
    'VEH_NO', 'DRDISTRACT',
]

cols_drimpair = [ 'ST_CASE',
    'VEH_NO', 'DRIMPAIR',
]

cols_person = [ 'ST_CASE',
    'VEH_NO', 'PER_NO',  
    'SPEC_USE', 
    'AGE', 'SEX', 'PER_TYP', 'INJ_SEV', 'REST_USE', 'REST_MIS', 'HELM_USE', 
    'HELM_MIS', 'AIR_BAG', 'EJECTION', 'DRINKING', 'ALC_STATUS', 'ATST_TYP', 'ALC_RES', 'DRUGS', 
    'STR_VEH', 'LOCATION'
]

cols_vehicle = [ 'ST_CASE',
    'VEH_NO', 'VE_FORMS', 'NUMOCCS', 'HIT_RUN', 'VIN', 
    'MOD_YEAR', 'VPICMAKE', 'VPICMODEL', 'VPICBODYCLASS', 'MAKE', 'MODEL', 'BODY_TYP', 'TOW_VEH', 
    'CARGO_BT', 'HAZ_INV', 'EMER_USE', 'TRAV_SP', 'DR_PRES', 'MAK_MOD', 'DR_ZIP', 'SPEEDREL', 
    'VTRAFWAY', 'VSPD_LIM', 'VSURCOND'
]

cols_vision = [ 'ST_CASE',
    'VEH_NO', 'VISION',
]

# %%
import pandas as pd
import os


# script_dir = os.getcwd()

# csv_path = os.path.join(script_dir, str(DATA_DIR / 'accident.csv'))



#
csv_path = str(DATA_DIR / 'accident.csv')

df = pd.read_csv(csv_path, usecols=cols_accident)

df.to_csv(str(DATA_DIR / 'AI-UNITE_FARS_accident_subset.csv'), index=False)

#
csv_path = str(DATA_DIR / 'distract.csv')

df = pd.read_csv(csv_path, usecols=cols_distract)

df.to_csv(str(DATA_DIR / 'AI-UNITE_FARS_distract_subset.csv'), index=False)

#
csv_path = str(DATA_DIR / 'drimpair.csv')
df = pd.read_csv(csv_path, usecols=cols_drimpair)

df.to_csv(str(DATA_DIR / 'AI-UNITE_FARS_drimpair_subset.csv'), index=False)

#
csv_path = str(DATA_DIR / 'vehicle.csv')
df = pd.read_csv(csv_path, usecols=cols_vehicle)

df.to_csv(str(DATA_DIR / 'AI-UNITE_FARS_vehicle_subset.csv'), index=False)

#
csv_path = str(DATA_DIR / 'person.csv')
df = pd.read_csv(csv_path, usecols=cols_person)

df.to_csv(str(DATA_DIR / 'AI-UNITE_FARS_person_subset.csv'), index=False)

#
csv_path = str(DATA_DIR / 'vision.csv')
df = pd.read_csv(csv_path, usecols=cols_vision)

df.to_csv(str(DATA_DIR / 'AI-UNITE_FARS_vision_subset.csv'), index=False)

# %%
df_person = pd.read_csv(str(DATA_DIR / 'AI-UNITE_FARS_accident_subset.csv'))
print(df_person.columns.tolist())
print(df_person.dtypes)
print(df_person.shape)

# %%
df_vehicle = pd.read_csv(str(DATA_DIR / 'AI-UNITE_FARS_vehicle_subset.csv'))
df_accident = pd.read_csv(str(DATA_DIR / 'AI-UNITE_FARS_accident_subset.csv'))

print("Vehicle shape:", df_vehicle.shape, "Accident shape:", df_accident.shape)

df_vehicle['merge_idx'] = df_vehicle.groupby('ST_CASE').cumcount()
df_accident['merge_idx'] = df_accident.groupby('ST_CASE').cumcount()

matching_rows = df_vehicle[df_vehicle['ST_CASE'].isin(df_accident['ST_CASE'])]

df_merged = df_vehicle.merge(
    df_accident,
    how="left",
    on=["ST_CASE", "merge_idx"]
)

print(df_merged.shape)  

df_merged.to_csv(str(DATA_DIR / 'AI-UNITE_FARS_accident_vehicle_merge.csv'), index=False)

# %%
df_merged = pd.read_csv(str(DATA_DIR / 'AI-UNITE_FARS_accident_vehicle_merge.csv'))
df_person = pd.read_csv(str(DATA_DIR / 'AI-UNITE_FARS_person_subset.csv'))

print(df_person.columns.tolist())
df_person_drivers = df_person[df_person["PER_TYP"] == 1].copy()


df_person_drivers['merge_idx'] = df_person_drivers.groupby('ST_CASE').cumcount()
df_merged['merge_idx'] = df_merged.groupby('ST_CASE').cumcount()

matching_rows = df_merged[df_merged['ST_CASE'].isin(df_person['ST_CASE'])]

df_merged = df_merged.merge(
    df_person_drivers,
    how="left",
    on=["ST_CASE", "VEH_NO"],
)

print(matching_rows)


df_merged = df_merged.rename(columns={'merge_idx_x': 'merge_idx'})
df_merged = df_merged.rename(columns={'merge_idx_y': 'merge_idx'})
df_merged = df_merged.drop(columns = 'merge_idx')

df_merged.to_csv(str(DATA_DIR / 'AI-UNITE_FARS_accident_person_vehicle_merge.csv'), index=False)

# %%
import pandas as pd

df_merged = pd.read_csv(str(DATA_DIR / 'AI-UNITE_FARS_accident_person_vehicle_merge.csv'))
df_drimpair = pd.read_csv(str(DATA_DIR / 'AI-UNITE_FARS_drimpair_subset.csv'))


common = df_merged['ST_CASE'].isin(df_merged['ST_CASE'])
df_merged = df_merged[common].copy()
df_drimpair = df_drimpair[df_drimpair['ST_CASE'].isin(df_merged['ST_CASE'])].copy()

df_merged['merge_idx'] = df_merged.groupby('ST_CASE').cumcount()
df_drimpair['merge_idx'] = df_drimpair.groupby('ST_CASE').cumcount()


df_merged = df_merged.merge(
    df_drimpair,
    how='left',
    on=['ST_CASE', 'merge_idx']  
)

df_merged = df_merged.rename(columns={'merge_idx_x': 'merge_idx'})
df_merged = df_merged.rename(columns={'merge_idx_y': 'merge_idx'})
df_merged = df_merged.drop(columns = 'merge_idx')

df_merged.to_csv(str(DATA_DIR / 'AI-UNITE_FARS_accident_person_vehicle_drimpair_merge.csv'), index=False)

print(df_merged.shape)

# %%
df_merged = pd.read_csv(str(DATA_DIR / 'AI-UNITE_FARS_accident_person_vehicle_drimpair_merge.csv'))
df_drimpair = pd.read_csv(str(DATA_DIR / 'AI-UNITE_FARS_distract_subset.csv'))

common = df_merged['ST_CASE'].isin(df_merged['ST_CASE'])
df_merged = df_merged[common].copy()
df_drimpair = df_drimpair[df_drimpair['ST_CASE'].isin(df_merged['ST_CASE'])].copy()

df_merged['merge_idx'] = df_merged.groupby('ST_CASE').cumcount()
df_drimpair['merge_idx'] = df_drimpair.groupby('ST_CASE').cumcount()


df_merged = df_merged.merge(
    df_drimpair,
    how='left',
    on=['ST_CASE', 'merge_idx']  
)

df_merged = df_merged.rename(columns={'merge_idx_x': 'merge_idx'})
df_merged = df_merged.rename(columns={'merge_idx_y': 'merge_idx'})
df_merged = df_merged.drop(columns = 'merge_idx')
df_merged = df_merged.drop(columns=['VEH_NO_y', 'VEH_NO_x'])
df_merged.to_csv(str(DATA_DIR / 'AI-UNITE_FARS_accident_person_vehicle_drimpair_distract_merge.csv'), index=False)

df_merged.to_csv(str(DATA_DIR / 'AI-UNITE_FARS_merged.csv'), index=False)
print(df_merged.shape)

# %%
df_merged = pd.read_csv(str(DATA_DIR / 'AI-UNITE_FARS_accident_person_vehicle_drimpair_distract_merge.csv'))
df_drimpair = pd.read_csv(str(DATA_DIR / 'AI-UNITE_FARS_vision_subset.csv'))

common = df_merged['ST_CASE'].isin(df_merged['ST_CASE'])
df_merged = df_merged[common].copy()
df_drimpair = df_drimpair[df_drimpair['ST_CASE'].isin(df_merged['ST_CASE'])].copy()

df_merged['merge_idx'] = df_merged.groupby('ST_CASE').cumcount()
df_drimpair['merge_idx'] = df_drimpair.groupby('ST_CASE').cumcount()


df_merged = df_merged.merge(
    df_drimpair,
    how='left',
    on=['ST_CASE', 'merge_idx']  
)

df_merged = df_merged.rename(columns={'merge_idx_x': 'merge_idx'})
df_merged = df_merged.rename(columns={'merge_idx_y': 'merge_idx'})
df_merged = df_merged.drop(columns = 'merge_idx')


df_merged.to_csv(str(DATA_DIR / 'AI-UNITE_FARS_accident_person_vehicle_drimpair_distractr_vision_merge.csv'), index=False)
df_merged.to_csv(str(DATA_DIR / 'AI-UNITE_FARS_merged.csv'), index=False)

print(df_merged.shape)

# %%
df_CRSS = pd.read_csv(str(DATA_DIR / 'AI-UNITE_CRSS_merged.csv'))
df_FARS = pd.read_csv(str(DATA_DIR / 'AI-UNITE_FARS_merged.csv'))

print("CRSS shape:", df_CRSS.shape)
print("FARS shape:", df_FARS.shape)


pd.concat([df_CRSS, df_FARS], ignore_index=True).to_csv(str(DATA_DIR / 'AI-UNITE_CRSS_FARS_merged.csv'), index=False)

# %%
df = pd.read_csv(str(DATA_DIR / 'AI-UNITE_CRSS_FARS_merged.csv'))
print(df.dtypes)

# %%
df = pd.read_csv(str(DATA_DIR / 'AI-UNITE_CRSS_FARS_merged.csv'))


categorical_cols = [    'PEDS', 'PERNOTMVIT', 'VE_TOTAL',  'PVH_INVL', 'PERMVIT', 
    'MONTH','DAY_WEEK', 'YEAR', 'HARM_EV', 'MAN_COLL', 'TYP_INT', 'REL_ROAD', 
    'WRK_ZONE', 'LGT_COND', 'WEATHER', 'DRDISTRACT','DRIMPAIR', 'PER_NO',  'SPEC_USE', 'AGE', 'SEX',
    'PER_TYP',  'REST_USE', 'REST_MIS', 'HELM_USE', 'HELM_MIS', 'AIR_BAG', 'EJECTION',
    'DRINKING', 'ALC_STATUS', 'ATST_TYP', 'ALC_RES', 'DRUGS', 'STR_VEH', 'LOCATION','VE_FORMS', 
    'HIT_RUN', 
    'BODY_TYP', 'TOW_VEH', 'CARGO_BT', 'HAZ_INV', 'EMER_USE', 'DR_PRES',
    'SPEEDREL', 'VTRAFWAY', 'VSPD_LIM', 'VSURCOND', 'VISION']

numeric_cols = ['TRAV_SP']

target = ['INJ_SEV']

features = categorical_cols + numeric_cols + target

df = df[features]

df.to_csv(str(DATA_DIR / 'TEST_AI_UNITE_CRSS_FARS_merged_subset.csv'), index=False)

# %%
df = pd.read_csv(str(DATA_DIR / 'TEST_AI_UNITE_CRSS_FARS_merged_subset.csv'))

df.dropna(subset=['YEAR'], inplace=True)

df['INJ_SEV'].replace({

    0: 0, 9: 0,           # No apparent injury
    1: 1, 2: 1,          # Possible + Suspected minor  Level1
    3: 2,                # Suspected serious           Level2
    4: 3, 5: 3, 6: 3   # Fatal & very severe     Level3
    },
    inplace=True
)

df.to_csv(str(DATA_DIR / 'TEST_AI_UNITE_CRSS_FARS_merged_subset1.csv'), index=False)


df.describe()

# %%
import pandas as pd

df = pd.read_csv(str(DATA_DIR / 'TEST_AI_UNITE_CRSS_FARS_merged_subset1.csv'))



df = df[df['DRIMPAIR'] != 9]
df = df[df['DRIMPAIR'] != 0]
df = df[df['DRIMPAIR'] != 98]
df = df[df['DRIMPAIR'] != 99]
df.to_csv(str(DATA_DIR / 'TEST_AI_UNITE_CRSS_FARS_merged_subset2.csv'), index=False)


df.describe()

# %%
df = pd.read_csv(str(DATA_DIR / 'TEST_AI_UNITE_CRSS_FARS_merged_subset1.csv'))

df.to_csv(str(DATA_DIR / 'AI_UNITE_CRSS_FARS_merged_IMPAIRMENT_ONLY.csv'), index=False)

# %%
import pandas as pd
import numpy as np
import os
from sklearn.model_selection import train_test_split, GridSearchCV, StratifiedKFold
from sklearn.preprocessing import OneHotEncoder, StandardScaler, OrdinalEncoder
from sklearn.compose import ColumnTransformer, make_column_transformer
from sklearn.pipeline import Pipeline
from sklearn.ensemble import HistGradientBoostingClassifier
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
import matplotlib.pyplot as plt
from sklearn.model_selection import RandomizedSearchCV
import time
from category_encoders import TargetEncoder  

script_dir = os.getcwd()
csv_path = os.path.join(script_dir, str(DATA_DIR / 'TEST_AI_UNITE_CRSS_FARS_merged_subset1.csv'))
df = pd.read_csv(csv_path, encoding='latin-1')




features = [
    'PEDS', 'PERNOTMVIT', 'VE_TOTAL',  'PVH_INVL', 'PERMVIT', 
    'MONTH','DAY_WEEK', 'YEAR', 'HOUR', 'MINUTE', 'HARM_EV', 'MAN_COLL', 'TYP_INT', 'REL_ROAD', 
    'WRK_ZONE', 'LGT_COND', 'WEATHER', 'DRDISTRACT','DRIMPAIR', 'PER_NO',  'SPEC_USE', 'AGE', 'SEX',
    'PER_TYP',  'REST_USE', 'REST_MIS', 'HELM_USE', 'HELM_MIS', 'AIR_BAG', 'EJECTION',
    'DRINKING', 'ALC_STATUS', 'ATST_TYP', 'ALC_RES', 'DRUGS', 'STR_VEH', 'LOCATION','VE_FORMS', 
    'NUMOCCS', 'HIT_RUN', 'VIN', 'MOD_YEAR', 'VPICMAKE', 'VPICMODEL', 'VPICBODYCLASS', 'MAKE', 'MODEL',
    'BODY_TYP', 'TOW_VEH', 'CARGO_BT', 'HAZ_INV', 'EMER_USE', 'TRAV_SP', 'DR_PRES', 'MAK_MOD', 
    'DR_ZIP', 'SPEEDREL', 'VTRAFWAY', 'VSPD_LIM', 'VSURCOND', 'VISION'
]



categorical_cols = [    
    'PEDS', 'PERNOTMVIT', 'VE_TOTAL',  'PVH_INVL', 'PERMVIT', 
    'MONTH','DAY_WEEK', 'YEAR', 'HARM_EV', 'MAN_COLL', 'TYP_INT', 'REL_ROAD', 
    'WRK_ZONE', 'LGT_COND', 'WEATHER', 'DRDISTRACT','DRIMPAIR', 'PER_NO',  'SPEC_USE', 'AGE', 'SEX',
    'PER_TYP',  'REST_USE', 'REST_MIS', 'HELM_USE', 'HELM_MIS', 'AIR_BAG', 'EJECTION',
    'DRINKING', 'ALC_STATUS', 'ATST_TYP', 'ALC_RES', 'DRUGS', 'STR_VEH', 'LOCATION','VE_FORMS', 
    'HIT_RUN', 'BODY_TYP', 'TOW_VEH', 'CARGO_BT', 'HAZ_INV', 'EMER_USE', 'DR_PRES',
    'SPEEDREL', 'VTRAFWAY', 'VSPD_LIM', 'VSURCOND', 'VISION']

numeric_cols = ['TRAV_SP']

features = categorical_cols + numeric_cols


df = df.dropna(subset=['INJ_SEV'])

df['INJ_SEV'] = df['INJ_SEV'].astype(int)


X = df[features].copy()
y = df['INJ_SEV']

# %%
# te  = TargetEncoder(
#         min_samples_leaf=20,
#         smoothing=5,
#         handle_unknown="value"
# )

# preproc = ColumnTransformer([
#         ("cat_te", te,  categorical_cols),
#         ("num_sc", StandardScaler(), numeric_cols)
# ])

# # ----- model --------------------------------------------------------------
# clf = HistGradientBoostingClassifier(
#         learning_rate=0.05,
#         max_depth=8,
#         max_iter=400,
#         early_stopping=True
# )

# pipe = Pipeline([("prep", preproc),
#                  ("clf",  clf)])

# %%
import pandas as pd
import numpy as np
import os
from sklearn.model_selection import train_test_split, GridSearchCV, StratifiedKFold, cross_val_score
from sklearn.preprocessing import OneHotEncoder, StandardScaler, OrdinalEncoder
from sklearn.compose import ColumnTransformer, make_column_transformer
from sklearn.pipeline import Pipeline
from sklearn.ensemble import HistGradientBoostingClassifier
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score, roc_auc_score
import matplotlib.pyplot as plt
from sklearn.model_selection import RandomizedSearchCV
from category_encoders import TargetEncoder  



script_dir = os.getcwd()
csv_path = os.path.join(script_dir, str(DATA_DIR / 'TEST_AI_UNITE_CRSS_FARS_merged_subset1.csv'))
df = pd.read_csv(csv_path, encoding='latin-1')

categorical_cols = [    
    'PEDS', 'PERNOTMVIT', 'VE_TOTAL',  'PVH_INVL', 'PERMVIT', 
    'MONTH','DAY_WEEK', 'YEAR', 'HARM_EV', 'MAN_COLL', 'TYP_INT', 'REL_ROAD', 
    'WRK_ZONE', 'LGT_COND', 'WEATHER', 'DRDISTRACT','DRIMPAIR', 'PER_NO',  'SPEC_USE', 'AGE', 'SEX',
    'REST_USE', 'REST_MIS', 'HELM_USE', 'HELM_MIS', 'AIR_BAG', 'EJECTION',
    'DRINKING', 'ALC_STATUS', 'ATST_TYP', 'ALC_RES', 'DRUGS', 'STR_VEH', 'LOCATION','VE_FORMS', 
    'HIT_RUN', 'BODY_TYP', 'TOW_VEH', 'CARGO_BT', 'HAZ_INV', 'EMER_USE', 'DR_PRES',
    'SPEEDREL', 'VTRAFWAY', 'VSPD_LIM', 'VSURCOND', 'VISION'
    ]

numeric_cols = ['TRAV_SP']

features = categorical_cols + numeric_cols


df = df.dropna(subset=['INJ_SEV'])

df['INJ_SEV'] = df['INJ_SEV'].astype(int)


X = df[features].copy()
y = df['INJ_SEV']


te  = TargetEncoder(
        min_samples_leaf=20,
        smoothing=5,
        handle_unknown="value"
)

preproc = ColumnTransformer([
        ("cat_te", te,  categorical_cols),
        ("num_sc", StandardScaler(), numeric_cols)
])

clf = HistGradientBoostingClassifier(
        learning_rate=0.05,
        max_depth=8,
        max_iter=400,
        early_stopping=True
)

pipe = Pipeline([("prep", preproc),
                 ("clf",  clf)])

cv  = StratifiedKFold(n_splits=3, shuffle=True, random_state=42)
auc = cross_val_score(pipe, X, y, cv=cv,
                      scoring="roc_auc_ovo_weighted").mean()
print("3-fold AUROC:", round(auc, 4))

# %%
import xgboost as xgb
from sklearn.model_selection import train_test_split, StratifiedKFold, cross_val_score
import pandas as pd

df = pd.read_csv(str(DATA_DIR / 'TEST_AI_UNITE_CRSS_FARS_merged_subset1.csv'), encoding='latin-1')
df = df.dropna(subset=['INJ_SEV'])
df['INJ_SEV'] = df['INJ_SEV'].astype(int)

X = df[features].copy()
y = df['INJ_SEV']

# cast every cat column to pandas category since XGBoost sees them as ints
for col in categorical_cols:
    X[col] = X[col].astype('category')

X['TRAV_SP'] = X['TRAV_SP'].astype(float)   # keep numeric as float

model = xgb.XGBClassifier(
            tree_method="hist",
            enable_categorical=True,
            objective="multi:softprob",
            num_class=4,
            n_estimators=800,
            learning_rate=0.05,
            max_depth=8,
            eval_metric="mlogloss")

cv  = StratifiedKFold(n_splits=3, shuffle=True, random_state=42)

auc = cross_val_score(model, X, y, cv=cv,
                      scoring="roc_auc_ovo_weighted").mean()
                      
print("3-fold AUROC:", round(auc, 4))

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import (
    accuracy_score, classification_report, confusion_matrix
)
import seaborn as sns; import matplotlib.pyplot as plt


X_train, X_test, y_train, y_test = train_test_split(
    X, y,
    test_size=0.20,
    stratify=y,
    random_state=42
)


pipe.fit(X_train, y_train)

y_pred = pipe.predict(X_test)

# 4 ─ evaluate
print("Accuracy:", round(accuracy_score(y_test, y_pred), 4))
print("\nClassification report\n")
print(classification_report(y_test, y_pred, digits=3))

cm = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(6,4))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues",
            xticklabels=["Level0","Level1","Level2","Level3"],
            yticklabels=["Level0","Level1","Level2","Level3"])
plt.xlabel("Predicted"); plt.ylabel("True"); plt.title("Confusion matrix")
plt.show()

# %%
import pandas as pd, seaborn as sns, matplotlib.pyplot as plt
from sklearn.model_selection import (
    train_test_split, StratifiedKFold, cross_val_score
)
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.metrics import (
    roc_auc_score, accuracy_score, classification_report, confusion_matrix, balanced_accuracy_score
)
import xgboost as xgb
from sklearn.utils import compute_class_weight
import numpy as np



df = pd.read_csv(str(DATA_DIR / 'TEST_AI_UNITE_CRSS_FARS_merged_subset1.csv'), encoding='latin-1')
df = df.dropna(subset=['INJ_SEV'])
df['INJ_SEV'] = df['INJ_SEV'].astype(int)   

categorical_cols = [
    'PEDS','PERNOTMVIT','VE_TOTAL','PVH_INVL','PERMVIT','MONTH','DAY_WEEK','YEAR',
    'HARM_EV','MAN_COLL','TYP_INT','REL_ROAD','WRK_ZONE','LGT_COND','WEATHER',
    'DRDISTRACT','DRIMPAIR','PER_NO','SPEC_USE','AGE','SEX','REST_USE','REST_MIS',
    'HELM_USE','HELM_MIS','AIR_BAG','EJECTION','DRINKING','ALC_STATUS','ATST_TYP',
    'ALC_RES','DRUGS','STR_VEH','LOCATION','VE_FORMS','HIT_RUN','BODY_TYP','TOW_VEH',
    'CARGO_BT','HAZ_INV','EMER_USE','DR_PRES','SPEEDREL','VTRAFWAY','VSPD_LIM',
    'VSURCOND','VISION'
]
numeric_cols = ['TRAV_SP']
features      = categorical_cols + numeric_cols

X = df[features].copy()
y = df['INJ_SEV']


for col in categorical_cols:
    X[col] = X[col].astype('category')
X['TRAV_SP'] = X['TRAV_SP'].astype(float)


preproc = ColumnTransformer(
    transformers=[
        ('num_scale', StandardScaler(), numeric_cols)
    ],
    remainder='passthrough'  
)


xgb_clf = xgb.XGBClassifier(
    tree_method='hist',
    enable_categorical=True,     
    objective='multi:softprob',
    num_class=4,
    n_estimators=800,
    learning_rate=0.05,
    max_depth=8,
    eval_metric='mlogloss'
)

pipe = Pipeline([
    ('prep', preproc),
    ('clf',  xgb_clf)
])


# 3-fold stratified CV AUROC
cv = StratifiedKFold(n_splits=3, shuffle=True, random_state=42)
auc_cv = cross_val_score(
            pipe, X, y, cv=cv,
            scoring='roc_auc_ovo_weighted'
         ).mean()
print(f"3-fold CV AUROC: {auc_cv:.4f}")


X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.20, stratify=y, random_state=42)


# + balanced class weights
class_w = compute_class_weight('balanced', classes=np.unique(y_train), y=y_train)
row_w   = y_train.map(dict(zip(np.unique(y_train), class_w))).values

pipe.fit(X_train, y_train, clf__sample_weight=row_w)
# +


# NEED TO: Tune hyperparameters 



#pipe.fit(X_train, y_train)
y_pred  = pipe.predict(X_test)
y_prob  = pipe.predict_proba(X_test)

print("\nAccuracy:", round(balanced_accuracy_score(y_test, y_pred), 4))
print("Test AUROC:", round(
        roc_auc_score(y_test, y_prob, multi_class='ovo'), 4))
print("\nClassification report:\n",
      classification_report(y_test, y_pred, digits=3))

cm = confusion_matrix(y_test, y_pred)
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=['Lvl0','Lvl1','Lvl2','Lvl3'],
            yticklabels=['Lvl0','Lvl1','Lvl2','Lvl3'])
plt.xlabel('Predicted'); plt.ylabel('True')
plt.title('Confusion matrix'); plt.tight_layout(); plt.show()

# %%
import pandas as pd, seaborn as sns, matplotlib.pyplot as plt
from sklearn.model_selection import (
    train_test_split, StratifiedKFold, cross_val_score
)
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.metrics import (
    roc_auc_score, accuracy_score, classification_report, confusion_matrix, balanced_accuracy_score
)
import xgboost as xgb
from sklearn.utils import compute_class_weight
import numpy as np



df = pd.read_csv(str(DATA_DIR / 'TEST_AI_UNITE_CRSS_FARS_merged_subset1.csv'), encoding='latin-1')
df = df.dropna(subset=['INJ_SEV'])
df['INJ_SEV'] = df['INJ_SEV'].astype(int)   

categorical_cols = [
    'PEDS','PERNOTMVIT','VE_TOTAL','PVH_INVL','PERMVIT','MONTH','DAY_WEEK','YEAR',
    'HARM_EV','MAN_COLL','TYP_INT','REL_ROAD','WRK_ZONE','LGT_COND','WEATHER',
    'DRDISTRACT','DRIMPAIR','PER_NO','SPEC_USE','AGE','SEX','REST_USE','REST_MIS',
    'HELM_USE','HELM_MIS','AIR_BAG','EJECTION','DRINKING','ALC_STATUS','ATST_TYP',
    'ALC_RES','DRUGS','STR_VEH','LOCATION','VE_FORMS','HIT_RUN','BODY_TYP','TOW_VEH',
    'CARGO_BT','HAZ_INV','EMER_USE','DR_PRES','SPEEDREL','VTRAFWAY','VSPD_LIM',
    'VSURCOND','VISION'
]
numeric_cols = ['TRAV_SP']
features      = categorical_cols + numeric_cols

X = df[features].copy()
y = df['INJ_SEV']


for col in categorical_cols:
    X[col] = X[col].astype('category')
X['TRAV_SP'] = X['TRAV_SP'].astype(float)


preproc = ColumnTransformer(
    transformers=[
        ('num_scale', StandardScaler(), numeric_cols)
    ],
    remainder='passthrough'  
)


xgb_clf = xgb.XGBClassifier(
    tree_method='hist',
    enable_categorical=True,     
    objective='multi:softprob',
    num_class=4,
    n_estimators=800,
    learning_rate=0.05,
    max_depth=8,
    eval_metric='mlogloss'
)

pipe = Pipeline([
    ('prep', preproc),
    ('clf',  xgb_clf)
])


# 3-fold stratified CV AUROC
cv = StratifiedKFold(n_splits=3, shuffle=True, random_state=42)
auc_cv = cross_val_score(
            pipe, X, y, cv=cv,
            scoring='roc_auc_ovo_weighted'
         ).mean()
print(f"3-fold CV AUROC: {auc_cv:.4f}")


X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.20, stratify=y, random_state=42)


# + balanced class weights
class_w = compute_class_weight('balanced', classes=np.unique(y_train), y=y_train)
row_w   = y_train.map(dict(zip(np.unique(y_train), class_w))).values

pipe.fit(X_train, y_train, clf__sample_weight=row_w)
# +


# NEED TO: Tune hyperparameters 



#pipe.fit(X_train, y_train)
y_pred  = pipe.predict(X_test)
y_prob  = pipe.predict_proba(X_test)

print("\nAccuracy:", round(balanced_accuracy_score(y_test, y_pred), 4))
print("Test AUROC:", round(
        roc_auc_score(y_test, y_prob, multi_class='ovo'), 4))
print("\nClassification report:\n",
      classification_report(y_test, y_pred, digits=3))

cm = confusion_matrix(y_test, y_pred)
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=['Lvl0','Lvl1','Lvl2','Lvl3'],
            yticklabels=['Lvl0','Lvl1','Lvl2','Lvl3'])
plt.xlabel('Predicted'); plt.ylabel('True')
plt.title('Confusion matrix'); plt.tight_layout(); plt.show()

# %%
df = pd.read_csv(str(DATA_DIR / 'TEST_AI_UNITE_CRSS_FARS_merged_subset1.csv'), encoding='latin-1')

df = df[(df['DRIMPAIR'] >= 1) & (df['DRIMPAIR'] <= 96)]

df.to_csv(str(DATA_DIR / 'AI_UNITE_CRSS_FARS_merged_subset_DRIMPAIR_ONLY.csv'), index=False)

# %%
import pandas as pd, seaborn as sns, matplotlib.pyplot as plt
from sklearn.model_selection import (
    train_test_split, StratifiedKFold, cross_val_score
)
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.metrics import (
    roc_auc_score, accuracy_score, classification_report, confusion_matrix, balanced_accuracy_score
)
import xgboost as xgb
from sklearn.utils import compute_class_weight
import numpy as np



df = pd.read_csv(str(DATA_DIR / 'AI_UNITE_CRSS_FARS_merged_subset_DRIMPAIR_ONLY.csv'), encoding='latin-1')
df = df.dropna(subset=['INJ_SEV'])
df['INJ_SEV'] = df['INJ_SEV'].astype(int)   

categorical_cols = [
    'PEDS','PERNOTMVIT','VE_TOTAL','PVH_INVL','PERMVIT','MONTH','DAY_WEEK','YEAR',
    'HARM_EV','MAN_COLL','TYP_INT','REL_ROAD','WRK_ZONE','LGT_COND','WEATHER',
    'DRDISTRACT','DRIMPAIR','PER_NO','SPEC_USE','AGE','SEX','REST_USE','REST_MIS',
    'HELM_USE','HELM_MIS','AIR_BAG','EJECTION','DRINKING','ALC_STATUS','ATST_TYP',
    'ALC_RES','DRUGS','STR_VEH','LOCATION','VE_FORMS','HIT_RUN','BODY_TYP','TOW_VEH',
    'CARGO_BT','HAZ_INV','EMER_USE','DR_PRES','SPEEDREL','VTRAFWAY','VSPD_LIM',
    'VSURCOND','VISION'
]
numeric_cols = ['TRAV_SP']
features      = categorical_cols + numeric_cols

X = df[features].copy()
y = df['INJ_SEV']


for col in categorical_cols:
    X[col] = X[col].astype('category')
X['TRAV_SP'] = X['TRAV_SP'].astype(float)


preproc = ColumnTransformer(
    transformers=[
        ('num_scale', StandardScaler(), numeric_cols)
    ],
    remainder='passthrough'  
)


xgb_clf = xgb.XGBClassifier(
    tree_method='hist',
    enable_categorical=True,     
    objective='multi:softprob',
    num_class=4,
    n_estimators=800,
    learning_rate=0.05,
    max_depth=8,
    eval_metric='mlogloss'
)

pipe = Pipeline([
    ('prep', preproc),
    ('clf',  xgb_clf)
])


# 3-fold stratified CV AUROC
cv = StratifiedKFold(n_splits=3, shuffle=True, random_state=42)
auc_cv = cross_val_score(
            pipe, X, y, cv=cv,
            scoring='roc_auc_ovo_weighted'
         ).mean()
print(f"3-fold CV AUROC: {auc_cv:.4f}")


X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.20, stratify=y, random_state=42)


# + balanced class weights
class_w = compute_class_weight('balanced', classes=np.unique(y_train), y=y_train)
row_w   = y_train.map(dict(zip(np.unique(y_train), class_w))).values

pipe.fit(X_train, y_train, clf__sample_weight=row_w)
# +


# NEED TO: Tune hyperparameters 



#pipe.fit(X_train, y_train)
y_pred  = pipe.predict(X_test)
y_prob  = pipe.predict_proba(X_test)

print("\nAccuracy:", round(balanced_accuracy_score(y_test, y_pred), 4))
print("Test AUROC:", round(
        roc_auc_score(y_test, y_prob, multi_class='ovo'), 4))
print("\nClassification report:\n",
      classification_report(y_test, y_pred, digits=3))

cm = confusion_matrix(y_test, y_pred)
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=['Lvl0','Lvl1','Lvl2','Lvl3'],
            yticklabels=['Lvl0','Lvl1','Lvl2','Lvl3'])
plt.xlabel('Predicted'); plt.ylabel('True')
plt.title('Confusion matrix'); plt.tight_layout(); plt.show()

# %%
# categorical_cols = [    'PEDS', 'PERNOTMVIT', 'VE_TOTAL',  'PVH_INVL', 'PERMVIT', 
#     'MONTH','DAY_WEEK', 'YEAR', 'HOUR', 'HARM_EV', 'MAN_COLL', 'TYP_INT', 'REL_ROAD', 
#     'WRK_ZONE', 'LGT_COND', 'WEATHER', 'DRDISTRACT','DRIMPAIR', 'PER_NO',  'SPEC_USE', 'AGE', 'SEX',
#     'PER_TYP',  'REST_USE', 'REST_MIS', 'HELM_USE', 'HELM_MIS', 'AIR_BAG', 'EJECTION',
#     'DRINKING', 'ALC_STATUS', 'ATST_TYP', 'ALC_RES', 'DRUGS', 'STR_VEH', 'LOCATION','VE_FORMS', 
#     'NUMOCCS', 'HIT_RUN', 'MOD_YEAR', 'MAKE', 'MODEL',
#     'BODY_TYP', 'TOW_VEH', 'CARGO_BT', 'HAZ_INV', 'EMER_USE', 'DR_PRES', 'MAK_MOD', 
#     'DR_ZIP', 'SPEEDREL', 'VTRAFWAY', 'VSPD_LIM', 'VSURCOND', 'VISION']





# We have 61 features many of them are categorical, so we will use a pipeline to preprocess the data.
# We have lots of categorical data, so we will one-hot encode them however, we have a high-cardinality
# with many of the columns, so we will pipeline the encoders using a ColumnTransformer so we can
# one-hot encode low-cardinality categorical features and use target or hashing encoding for 
# high-cardinality features.

# LightGM / CATBoost will kep each columns as interger, zero preprocessing, no extra mem, works with shap
# or Target mean encoding with CV-based smoothing on features with high cardinality will
# replace each categorical value with the mean of the target variable for that category.
# Encoded values will be interpretable and have a standard deviation of 1. All columns will be
# numerical, so we can use any model that accepts numerical data.


# Target encoding with CV-based smoothing on features with high cardinality < 10

# DR_ZIP      18877
# MAK_MOD      1045
# ALC_RES       441
# MODEL         137
# AGE           100
# MOD_YEAR       85
# MAKE           66
# BODY_TYP       64
# HARM_EV        56
# NUMOCCS        43


# One-hot encode categorical data to a format that can be used in the model
#pd.get_dummies(X, columns=['WEATHER'], drop_first=True, dtype=int)
#df[categorical_cols].nunique().sort_values(ascending=False).head(10)

# %%
import pandas as pd, seaborn as sns, matplotlib.pyplot as plt
from sklearn.model_selection import (
    train_test_split, StratifiedKFold, cross_val_score
)
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.metrics import (
    roc_auc_score, accuracy_score, classification_report, confusion_matrix, balanced_accuracy_score, mean_absolute_error
)
import xgboost as xgb
from xgboost import XGBRegressor
from sklearn.utils import compute_class_weight
import numpy as np



df = pd.read_csv(str(DATA_DIR / 'TEST_AI_UNITE_CRSS_FARS_merged_subset1.csv'), encoding='latin-1')
df = df.dropna(subset=['INJ_SEV'])
df['INJ_SEV'] = df['INJ_SEV'].astype(int)   

categorical_cols = [
    'PEDS','PERNOTMVIT','VE_TOTAL','PVH_INVL','PERMVIT','MONTH','DAY_WEEK','YEAR',
    'HARM_EV','MAN_COLL','TYP_INT','REL_ROAD','WRK_ZONE','LGT_COND','WEATHER',
    'DRDISTRACT','DRIMPAIR','PER_NO','SPEC_USE','AGE','SEX','REST_USE','REST_MIS',
    'HELM_USE','HELM_MIS','AIR_BAG','EJECTION','DRINKING','ALC_STATUS','ATST_TYP',
    'ALC_RES','DRUGS','STR_VEH','LOCATION','VE_FORMS','HIT_RUN','BODY_TYP','TOW_VEH',
    'CARGO_BT','HAZ_INV','EMER_USE','DR_PRES','SPEEDREL','VTRAFWAY','VSPD_LIM',
    'VSURCOND','VISION'
]
numeric_cols = ['TRAV_SP']
features      = categorical_cols

X = df[features].copy()
y = df['INJ_SEV']
X_test_full = X.copy()
X_train_full, X_valid_full, y_train, y_valid = train_test_split(X, y, train_size=0.8, test_size=0.2,
                                                                random_state=0)
                                                                
X_train = X_train_full[features].copy()
X_valid = X_valid_full[features].copy()
X_test = X_test_full[features].copy()

for col in categorical_cols:
    X[col] = X[col].astype('category')


my_model = XGBRegressor(n_estimators=1000, learning_rate=0.05, early_stopping_rounds=5)

my_model.fit(X_train, y_train, 
             eval_set=[(X_valid, y_valid)], 
             verbose=False)

predictions = my_model.predict(X_valid)


print("Mean Absolute Error: " + str(mean_absolute_error(predictions, y_valid)))

# %%
ct.set_output(transform='pandas')

# %%
# !pip install lightgbm catboost shap

# %%
# !pip install xgboost category_encoders<2.4 scikit-learn>=1.4
